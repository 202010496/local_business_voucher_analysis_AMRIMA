# %%
#코로나 전 payment_사용금액(2019)

import pandas as pd
import numpy as np
import os

payment_2019 = pd.read_csv('C:\\Users\\user\\OneDrive\\바탕 화면\\포천시_지역화폐_병합\\포천_payment\\2019년_payment.csv', encoding='cp949')
payment_2019.head()
# Out:
#       USER_ID SERVICE_NAME                      CARD_NO GENDER  \
# 0  3002036036  포천사랑상품권(정책)  Q15FB64EC8F295F8A5D7B203FD3      여
# 1  3002130335  포천사랑상품권(정책)  Q18E8FE129F295FF6958E595D80      여
# 2  3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 3  3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 4  3002096635  포천사랑상품권(정책)  Q1B0B6E549F295FFEB8FAF88618      남
#
#   USER_BIRTH_YEAR                            USER_ADDRESS USER_GRADE_TYPE  \
# 0            1994  경기도 양주시 고읍남로 94 (광사동, 양주고읍 LH13단지 아파트)             정회원
# 1            1996                  경기도 포천시 군내면 용정경제로1길 14             정회원
# 2            1984     경기도 포천시 소흘읍 태봉로 239 (석향마을대방노블랜드아파트)             정회원
# 3            1984     경기도 포천시 소흘읍 태봉로 239 (석향마을대방노블랜드아파트)             정회원
# 4            1991  경기도 양주시 옥정동로 106 (옥정동, 금호건설제이드웰엔에이치에프)             정회원
#
#   MERCHANT_NAME MERCHANT_SALES_CODE  MERCHANT_BIZ_TYPE  ...  \
# 0          우리통닭                   8               8021  ...
# ...

# %%
total_2019 = payment_2019['PAYMENT_AMOUNT'].sum()
personal_2019 = payment_2019['BALANCE_AMOUNT'].sum()
policy_2019 = payment_2019['CASH_AMOUNT'].sum() 

total_2019, personal_2019, policy_2019
# Out:
# (1313353405, 55282637, 1258070768)

# %%
#코로나 후 payment_사용금액(2020)
forders = os.listdir('C:\\Users\\user\\OneDrive\\바탕 화면\\포천시_지역화폐_병합\\포천_payment\\2020년_payment')
print(forders)
# Out:
# ['2020년_payment(1).csv', '2020년_payment(2).csv', '2020년_payment(3).csv', '2020년_payment(4).csv']

# %%
df_all = pd.DataFrame()
for i in range(0,len(forders)):
    if forders[i].split('.')[1] == 'csv':
        file = 'C:\\Users\\user\\OneDrive\\바탕 화면\\포천시_지역화폐_병합\\포천_payment\\2020년_payment\\'+forders[i]
        df= pd.read_csv(file, encoding='cp949') 
        df_all = pd.concat([df_all, df])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
payment_2020 = df_all
payment_2020.head()
# Out:
#       USER_ID SERVICE_NAME                      CARD_NO GENDER  \
# 0  3012410118  포천사랑상품권(정책)  Q19D91508DF428C5FF8C321B172      여
# 1  3010711118  포천사랑상품권(정책)  Q13081BD44F29674E5EB5178704      남
# 2  3004195939  포천사랑상품권(정책)  Q1B1969C83F427D549EEDE611CE      남
# 3  3006133546  포천사랑상품권(정책)  Q13484B843F427D73DA55AED98D      여
# 4  3012410118  포천사랑상품권(정책)  Q19D91508DF428C5FF8C321B172      여
#
#   USER_BIRTH_YEAR                          USER_ADDRESS USER_GRADE_TYPE  \
# 0            1995                                  NONE             정회원
# 1            1995                  경기도 포천시 영중면 뻐꾹천1길 13             정회원
# 2            1994                                  NONE             정회원
# 3            1995  경기도 포천시 소흘읍 봉솔로 9 (영화I-NIX아파트(연봉마을))             정회원
# 4            1995                                  NONE             정회원
#
#   MERCHANT_NAME MERCHANT_SALES_CODE MERCHANT_BIZ_TYPE  ...  \
# 0        금강산갈비찜                   J              8001  ...
# ...

# %%
total_2020 = payment_2020['PAYMENT_AMOUNT'].sum()
personal_2020 = payment_2020['BALANCE_AMOUNT'].sum()
policy_2020 = payment_2020['CASH_AMOUNT'].sum() 

total_2020, personal_2020, policy_2020
# Out:
# (89552127292, 10089256122, 79462660170)

# %%
#코로나 후 payment_사용금액(2021)
forders = os.listdir('C:\\Users\\user\\OneDrive\\바탕 화면\\포천시_지역화폐_병합\\포천_payment\\2021년_payment')
print(forders)
# Out:
# ['2021년_payment(1).csv', '2021년_payment(2).csv', '2021년_payment(3).csv']

# %%
df_all = pd.DataFrame()
for i in range(0,len(forders)):
    if forders[i].split('.')[1] == 'csv':
        file = 'C:\\Users\\user\\OneDrive\\바탕 화면\\포천시_지역화폐_병합\\포천_payment\\2021년_payment\\'+forders[i]
        df= pd.read_csv(file, encoding='cp949') 
        df_all = pd.concat([df_all, df])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
payment_2021 = df_all
payment_2021.head()
# Out:
#       USER_ID SERVICE_NAME                      CARD_NO GENDER  \
# 0  3014752121      포천사랑상품권  Q15585B34AF75CB95BADBA319A4      남
# 1  3014752121      포천사랑상품권  Q15585B34AF75CB95BADBA319A4      남
# 2  3006218162      포천사랑상품권  Q165B595EAF75C65CA036A97F6D      남
# 3  3006218162      포천사랑상품권  Q165B595EAF75C65CA036A97F6D      남
# 4  3017397954      포천사랑상품권  Q1ED9E866713DB100C200F3EE6D      여
#
#   USER_BIRTH_YEAR                            USER_ADDRESS USER_GRADE_TYPE  \
# 0            1982  서울특별시 성북구 돌곶이로 220 (장위동, 꿈의숲코오롱하늘채아파트)             정회원
# 1            1982  서울특별시 성북구 돌곶이로 220 (장위동, 꿈의숲코오롱하늘채아파트)             정회원
# 2            1989                    경기도 포천시 중앙로 87 (신읍동)             정회원
# 3            1989                    경기도 포천시 중앙로 87 (신읍동)             정회원
# 4            1972                  경기도 포천시 호국로 1007 (선단동)             정회원
#
#   MERCHANT_NAME MERCHANT_SALES_CODE  MERCHANT_BIZ_TYPE  ...  \
# 0   이마트24 포천체육공                   A               4010  ...
# ...

# %%
total_2021 = payment_2021['PAYMENT_AMOUNT'].sum()
personal_2021 = payment_2021['BALANCE_AMOUNT'].sum()
policy_2021 = payment_2021['CASH_AMOUNT'].sum() 

total_2021, personal_2021, policy_2021
# Out:
# (42809547640, 11844831699, 30964491415)

# %%
# 시각화
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 시각화_상/하반기
import numpy as np


arr = np.empty((0,3), int)

arr = np.append(arr, np.array([[240670448, 1291830, 239378618]]), axis=0)     # 2019_1    # [[total, personal, policy]]
arr = np.append(arr, np.array([[1072682957, 53990807, 1018692150]]), axis=0)     # 2019_2
arr = np.append(arr, np.array([[63973897227, 1859997563, 62113899664]]), axis=0)     # 2020_1
arr = np.append(arr, np.array([[25578230065, 8229258559, 17348760506]]), axis=0)     # 2020_2    
arr = np.append(arr, np.array([[40472590959, 9878613182, 30593800433]]), axis=0)     # 2021_1
arr = np.append(arr, np.array([[2336956681, 1966218517, 370690982]]), axis=0)     # 2021_2



print(arr)
# Out:
# [[  240670448     1291830   239378618]
#  [ 1072682957    53990807  1018692150]
#  [63973897227  1859997563 62113899664]
#  [25578230065  8229258559 17348760506]
#  [40472590959  9878613182 30593800433]
#  [ 2336956681  1966218517   370690982]]

# %%
import pandas as pd

df1 = pd.DataFrame(arr, columns=['total', 'personal', 'policy'],
                 index=['2019_1', '2019_2', '2020_1', '2020_2', '2021_1', '2021_2'])

df1
# Out:
#               total    personal       policy
# 2019_1    240670448     1291830    239378618
# 2019_2   1072682957    53990807   1018692150
# 2020_1  63973897227  1859997563  62113899664
# 2020_2  25578230065  8229258559  17348760506
# 2021_1  40472590959  9878613182  30593800433
# 2021_2   2336956681  1966218517    370690982

# %%
# total
plt.figure(figsize=(6,6))
plt.rc("font", family='NanumGothic')
plt.title("total_payment")
x = np.arange(6)
years = ['2019_1', '2019_2', '2020_1', '2020_2', '2021_1', '2021_2']
values = df1['total']

plt.bar(x, values) #color=colors)
plt.xticks(x, years)


#plt.show()


# personal
plt.figure(figsize=(6,6))
plt.title("balance_payment")
x = np.arange(6)
years = ['2019_1', '2019_2', '2020_1', '2020_2', '2021_1', '2021_2']
values = df1['personal']

plt.bar(x, values, color='#e35f62')
plt.xticks(x, years)


#plt.show()



#policy
plt.figure(figsize=(6,6))
plt.title("policy_payment")
x = np.arange(6)
years = ['2019_1', '2019_2', '2020_1', '2020_2', '2021_1', '2021_2']
values = df1['policy']

plt.bar(x, values, color='g')
plt.xticks(x, years)

plt.show()

# %%
df1.plot(kind='bar')
plt.title("payment")
plt.show()

# %%
all_payment = pd.concat([payment_2019,payment_2020, payment_2021], ignore_index=True)

all_payment.head()
# Out:
#       USER_ID SERVICE_NAME                      CARD_NO GENDER  \
# 0  3002036036  포천사랑상품권(정책)  Q15FB64EC8F295F8A5D7B203FD3      여
# 1  3002130335  포천사랑상품권(정책)  Q18E8FE129F295FF6958E595D80      여
# 2  3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 3  3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 4  3002096635  포천사랑상품권(정책)  Q1B0B6E549F295FFEB8FAF88618      남
#
#   USER_BIRTH_YEAR                            USER_ADDRESS USER_GRADE_TYPE  \
# 0            1994  경기도 양주시 고읍남로 94 (광사동, 양주고읍 LH13단지 아파트)             정회원
# 1            1996                  경기도 포천시 군내면 용정경제로1길 14             정회원
# 2            1984     경기도 포천시 소흘읍 태봉로 239 (석향마을대방노블랜드아파트)             정회원
# 3            1984     경기도 포천시 소흘읍 태봉로 239 (석향마을대방노블랜드아파트)             정회원
# 4            1991  경기도 양주시 옥정동로 106 (옥정동, 금호건설제이드웰엔에이치에프)             정회원
#
#   MERCHANT_NAME MERCHANT_SALES_CODE MERCHANT_BIZ_TYPE  ...  \
# 0          우리통닭                   8              8021  ...
# ...

# %%
all_payment['MERCHANT_BIZ_TYPE'].astype(str)
# Out:
# 0          8021
# 1          8001
# 2          4010
# 3          4010
# 4          4010
#            ...
# 5187783    4010
# 5187784    6101
# 5187785    6101
# 5187786    4010
# 5187787    4010
# Name: MERCHANT_BIZ_TYPE, Length: 5187788, dtype: object

# %%
# 연령별
all_payment
# Out:
#             USER_ID SERVICE_NAME                      CARD_NO GENDER  \
# 0        3002036036  포천사랑상품권(정책)  Q15FB64EC8F295F8A5D7B203FD3      여
# 1        3002130335  포천사랑상품권(정책)  Q18E8FE129F295FF6958E595D80      여
# 2        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 3        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 4        3002096635  포천사랑상품권(정책)  Q1B0B6E549F295FFEB8FAF88618      남
# ...             ...          ...                          ...    ...
# 5187783  3041160185  포천사랑상품권(통합)  Q12DBE84B21BC854B0772FD0D97      남
# 5187784  3024124143      포천사랑상품권  Q1E7ABA6BA107D26AA7E85C596B      여
# 5187785  3024124143      포천사랑상품권  Q1E7ABA6BA107D26AA7E85C596B      여
# 5187786  3022522144      포천사랑상품권  Q195956C28107A5C20792A1EEE8      남
# 5187787  3022522144      포천사랑상품권  Q195956C28107A5C20792A1EEE8      남
#
#         USER_BIRTH_YEAR                            USER_ADDRESS  \
# 0                  1994  경기도 양주시 고읍남로 94 (광사동, 양주고읍 LH13단지 아파트)
# ...

# %%
# 출생연도가 NONE인 행 제거

all_payment_uby_dropNONE = all_payment[~all_payment['USER_BIRTH_YEAR'].str.contains("NONE", na=False, case=False)]

all_payment_uby_dropNONE
# Out:
#             USER_ID SERVICE_NAME                      CARD_NO GENDER  \
# 0        3002036036  포천사랑상품권(정책)  Q15FB64EC8F295F8A5D7B203FD3      여
# 1        3002130335  포천사랑상품권(정책)  Q18E8FE129F295FF6958E595D80      여
# 2        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 3        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 4        3002096635  포천사랑상품권(정책)  Q1B0B6E549F295FFEB8FAF88618      남
# ...             ...          ...                          ...    ...
# 5187783  3041160185  포천사랑상품권(통합)  Q12DBE84B21BC854B0772FD0D97      남
# 5187784  3024124143      포천사랑상품권  Q1E7ABA6BA107D26AA7E85C596B      여
# 5187785  3024124143      포천사랑상품권  Q1E7ABA6BA107D26AA7E85C596B      여
# 5187786  3022522144      포천사랑상품권  Q195956C28107A5C20792A1EEE8      남
# 5187787  3022522144      포천사랑상품권  Q195956C28107A5C20792A1EEE8      남
#
#         USER_BIRTH_YEAR                            USER_ADDRESS  \
# 0                  1994  경기도 양주시 고읍남로 94 (광사동, 양주고읍 LH13단지 아파트)
# ...

# %%
all_payment_uby_dropNONE = all_payment_uby_dropNONE.astype({'USER_BIRTH_YEAR':'int'})

# %%
age = 2021 - all_payment_uby_dropNONE['USER_BIRTH_YEAR'] + 1
all_payment_uby_dropNONE['AGE'] = age
all_payment_uby_dropNONE
# Out:
#             USER_ID SERVICE_NAME                      CARD_NO GENDER  \
# 0        3002036036  포천사랑상품권(정책)  Q15FB64EC8F295F8A5D7B203FD3      여
# 1        3002130335  포천사랑상품권(정책)  Q18E8FE129F295FF6958E595D80      여
# 2        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 3        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 4        3002096635  포천사랑상품권(정책)  Q1B0B6E549F295FFEB8FAF88618      남
# ...             ...          ...                          ...    ...
# 5187783  3041160185  포천사랑상품권(통합)  Q12DBE84B21BC854B0772FD0D97      남
# 5187784  3024124143      포천사랑상품권  Q1E7ABA6BA107D26AA7E85C596B      여
# 5187785  3024124143      포천사랑상품권  Q1E7ABA6BA107D26AA7E85C596B      여
# 5187786  3022522144      포천사랑상품권  Q195956C28107A5C20792A1EEE8      남
# 5187787  3022522144      포천사랑상품권  Q195956C28107A5C20792A1EEE8      남
#
#          USER_BIRTH_YEAR                            USER_ADDRESS  \
# 0                   1994  경기도 양주시 고읍남로 94 (광사동, 양주고읍 LH13단지 아파트)
# ...

# %%
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (18, 8)

#plt.subplot(1, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(all_payment_uby_dropNONE['AGE'], color='green')
plt.title('Age', fontsize = 20)
plt.xlabel('Age')
plt.ylabel('Rate')
# Out:
# Text(0, 0.5, 'Rate')

# %%
all_payment1 = all_payment[all_payment['USER_BIRTH_YEAR'].str.contains('18')]
all_payment1

# 164세 ,,,???
# Out:
#             USER_ID SERVICE_NAME                      CARD_NO GENDER  \
# 498819   3021536236      포천사랑상품권  Q12EB89B4B107F104B736EFF702      여
# 778528   3021536236      포천사랑상품권  Q12EB89B4B107F104B736EFF702      여
# 785744   3021536236      포천사랑상품권  Q12EB89B4B107F104B736EFF702      여
# 822793   3021536236      포천사랑상품권  Q12EB89B4B107F104B736EFF702      여
# 928531   3021536236      포천사랑상품권  Q12EB89B4B107F104B736EFF702      여
# 941348   3021536236      포천사랑상품권  Q12EB89B4B107F104B736EFF702      여
# 1033806  3021536236      포천사랑상품권  Q12EB89B4B107F104B736EFF702      여
# 1042371  3021536236      포천사랑상품권  Q12EB89B4B107F104B736EFF702      여
# 1126200  3021536236      포천사랑상품권  Q12EB89B4B107F104B736EFF702      여
# 1173369  3021536236      포천사랑상품권  Q12EB89B4B107F104B736EFF702      여
# 1185731  3021536236      포천사랑상품권  Q12EB89B4B107F104B736EFF702      여
# 1192542  3021536236      포천사랑상품권  Q12EB89B4B107F104B736EFF702      여
# 1265530  3021536236      포천사랑상품권  Q12EB89B4B107F104B736EFF702      여
# ...

# %%
# 100세 이상 행 제거

condition = (all_payment_uby_dropNONE.AGE < 100)

payment_dropNONE_0_100 = all_payment_uby_dropNONE[condition]
payment_dropNONE_0_100
# Out:
#             USER_ID SERVICE_NAME                      CARD_NO GENDER  \
# 0        3002036036  포천사랑상품권(정책)  Q15FB64EC8F295F8A5D7B203FD3      여
# 1        3002130335  포천사랑상품권(정책)  Q18E8FE129F295FF6958E595D80      여
# 2        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 3        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 4        3002096635  포천사랑상품권(정책)  Q1B0B6E549F295FFEB8FAF88618      남
# ...             ...          ...                          ...    ...
# 5187783  3041160185  포천사랑상품권(통합)  Q12DBE84B21BC854B0772FD0D97      남
# 5187784  3024124143      포천사랑상품권  Q1E7ABA6BA107D26AA7E85C596B      여
# 5187785  3024124143      포천사랑상품권  Q1E7ABA6BA107D26AA7E85C596B      여
# 5187786  3022522144      포천사랑상품권  Q195956C28107A5C20792A1EEE8      남
# 5187787  3022522144      포천사랑상품권  Q195956C28107A5C20792A1EEE8      남
#
#          USER_BIRTH_YEAR                            USER_ADDRESS  \
# 0                   1994  경기도 양주시 고읍남로 94 (광사동, 양주고읍 LH13단지 아파트)
# ...

# %%
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (18, 8)

#plt.subplot(1, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(payment_dropNONE_0_100['AGE'], color='green')
plt.title('Age', fontsize = 20)
plt.xlabel('Age')
plt.ylabel('Rate')
# Out:
# Text(0, 0.5, 'Rate')

# %%
# 남자/여자 연령별 비율
condition = (all_payment.GENDER == '여')

all_payment_wm = all_payment[condition]
all_payment_wm
# Out:
#             USER_ID SERVICE_NAME                      CARD_NO GENDER  \
# 0        3002036036  포천사랑상품권(정책)  Q15FB64EC8F295F8A5D7B203FD3      여
# 1        3002130335  포천사랑상품권(정책)  Q18E8FE129F295FF6958E595D80      여
# 2        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 3        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 6        3002143781  포천사랑상품권(정책)  Q17E9D6D06F295F95675EB2C8ED      여
# ...             ...          ...                          ...    ...
# 5187775  3017172546      포천사랑상품권  Q1A99214DB13DB736675BAEF383      여
# 5187776  3017172546      포천사랑상품권  Q1A99214DB13DB736675BAEF383      여
# 5187777  3011879100      포천사랑상품권  Q185BA562410365D40C0AB7A5BF      여
# 5187784  3024124143      포천사랑상품권  Q1E7ABA6BA107D26AA7E85C596B      여
# 5187785  3024124143      포천사랑상품권  Q1E7ABA6BA107D26AA7E85C596B      여
#
#         USER_BIRTH_YEAR                            USER_ADDRESS  \
# 0                  1994  경기도 양주시 고읍남로 94 (광사동, 양주고읍 LH13단지 아파트)
# ...

# %%
condition = (all_payment.GENDER == '남')

all_payment_m = all_payment[condition]
all_payment_m
# Out:
#             USER_ID SERVICE_NAME                      CARD_NO GENDER  \
# 4        3002096635  포천사랑상품권(정책)  Q1B0B6E549F295FFEB8FAF88618      남
# 5        3002140345  포천사랑상품권(정책)  Q114889063F295F935AE4DDD047      남
# 15       3002140345  포천사랑상품권(정책)  Q114889063F295F935AE4DDD047      남
# 18       3002140345  포천사랑상품권(정책)  Q114889063F295F935AE4DDD047      남
# 19       3002096635  포천사랑상품권(정책)  Q1B0B6E549F295FFEB8FAF88618      남
# ...             ...          ...                          ...    ...
# 5187781  3017583846      포천사랑상품권  Q135A84E0713DB4D4939E810069      남
# 5187782  3041160185  포천사랑상품권(통합)  Q12DBE84B21BC854B0772FD0D97      남
# 5187783  3041160185  포천사랑상품권(통합)  Q12DBE84B21BC854B0772FD0D97      남
# 5187786  3022522144      포천사랑상품권  Q195956C28107A5C20792A1EEE8      남
# 5187787  3022522144      포천사랑상품권  Q195956C28107A5C20792A1EEE8      남
#
#         USER_BIRTH_YEAR                            USER_ADDRESS  \
# 4                  1991  경기도 양주시 옥정동로 106 (옥정동, 금호건설제이드웰엔에이치에프)
# ...

# %%
all_payment_uby_dropNONE_m = all_payment_m[~all_payment_m['USER_BIRTH_YEAR'].str.contains("NONE", na=False, case=False)]

all_payment_uby_dropNONE_wm = all_payment_wm[~all_payment_wm['USER_BIRTH_YEAR'].str.contains("NONE", na=False, case=False)]

all_payment_uby_dropNONE_m = all_payment_uby_dropNONE_m.astype({'USER_BIRTH_YEAR':'int'})
all_payment_uby_dropNONE_wm = all_payment_uby_dropNONE_wm.astype({'USER_BIRTH_YEAR':'int'})


age_m = 2021 - all_payment_uby_dropNONE_m['USER_BIRTH_YEAR'] + 1
all_payment_uby_dropNONE_m['AGE'] = age_m

age_wm = 2021 - all_payment_uby_dropNONE_wm['USER_BIRTH_YEAR'] + 1
all_payment_uby_dropNONE_wm['AGE'] = age_wm

# %%
condition = (all_payment_uby_dropNONE_wm.AGE < 100)

payment_dropNONE_0_100_wm = all_payment_uby_dropNONE_wm[condition]
payment_dropNONE_0_100_wm
# Out:
#             USER_ID SERVICE_NAME                      CARD_NO GENDER  \
# 0        3002036036  포천사랑상품권(정책)  Q15FB64EC8F295F8A5D7B203FD3      여
# 1        3002130335  포천사랑상품권(정책)  Q18E8FE129F295FF6958E595D80      여
# 2        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 3        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 6        3002143781  포천사랑상품권(정책)  Q17E9D6D06F295F95675EB2C8ED      여
# ...             ...          ...                          ...    ...
# 5187775  3017172546      포천사랑상품권  Q1A99214DB13DB736675BAEF383      여
# 5187776  3017172546      포천사랑상품권  Q1A99214DB13DB736675BAEF383      여
# 5187777  3011879100      포천사랑상품권  Q185BA562410365D40C0AB7A5BF      여
# 5187784  3024124143      포천사랑상품권  Q1E7ABA6BA107D26AA7E85C596B      여
# 5187785  3024124143      포천사랑상품권  Q1E7ABA6BA107D26AA7E85C596B      여
#
#          USER_BIRTH_YEAR                            USER_ADDRESS  \
# 0                   1994  경기도 양주시 고읍남로 94 (광사동, 양주고읍 LH13단지 아파트)
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (18, 8)

plt.subplot(1, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(all_payment_uby_dropNONE_m['AGE'])
plt.title('Age_men', fontsize = 20)
plt.xlabel('Age')
plt.ylabel('Rate')


plt.subplot(1, 2, 2)
sns.set(style = 'whitegrid')
sns.distplot(payment_dropNONE_0_100_wm['AGE'], color = 'red')
plt.title('Age_women', fontsize = 20)
plt.xlabel('Age')
plt.ylabel('Rate')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumGothic')
print(plt.rcParams['font.family'])

# %matplotlib inline
# Out:
# ['NanumGothic']

# %%
# 남녀 비율
plt.figure(1,figsize=(15,5))
sns.countplot(y='GENDER',data=payment_dropNONE_0_100)
plt.show()

# %%
condition = (payment_dropNONE_0_100.PAYMENT_AMOUNT > 0)

payment_dropNONE_0_100_pay = payment_dropNONE_0_100[condition]
payment_dropNONE_0_100_pay


condition = (payment_dropNONE_0_100.BALANCE_AMOUNT > 0)

payment_dropNONE_0_100_bal = payment_dropNONE_0_100[condition]
payment_dropNONE_0_100_bal


condition = (payment_dropNONE_0_100.CASH_AMOUNT > 0)

payment_dropNONE_0_100_cash = payment_dropNONE_0_100[condition]
payment_dropNONE_0_100_cash
# Out:
#             USER_ID SERVICE_NAME                      CARD_NO GENDER  \
# 0        3002036036  포천사랑상품권(정책)  Q15FB64EC8F295F8A5D7B203FD3      여
# 1        3002130335  포천사랑상품권(정책)  Q18E8FE129F295FF6958E595D80      여
# 2        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 3        3002118626  포천사랑상품권(정책)  Q1D9941C91F295FE3BF6241F6D5      여
# 4        3002096635  포천사랑상품권(정책)  Q1B0B6E549F295FFEB8FAF88618      남
# ...             ...          ...                          ...    ...
# 5187778  3017284644      포천사랑상품권  Q1348B385EFFA02E04DD919E099      남
# 5187780  3017583846      포천사랑상품권  Q135A84E0713DB4D4939E810069      남
# 5187782  3041160185  포천사랑상품권(통합)  Q12DBE84B21BC854B0772FD0D97      남
# 5187784  3024124143      포천사랑상품권  Q1E7ABA6BA107D26AA7E85C596B      여
# 5187786  3022522144      포천사랑상품권  Q195956C28107A5C20792A1EEE8      남
#
#          USER_BIRTH_YEAR                            USER_ADDRESS  \
# 0                   1994  경기도 양주시 고읍남로 94 (광사동, 양주고읍 LH13단지 아파트)
# ...

# %%
w = payment_dropNONE_0_100['AGE']
x = payment_dropNONE_0_100_pay['PAYMENT_AMOUNT']
y = payment_dropNONE_0_100_bal['BALANCE_AMOUNT']
z = payment_dropNONE_0_100_cash['CASH_AMOUNT'] 

                                
sns.lineplot(w, x, color = 'blue')
sns.lineplot(w, y, color = 'pink')
sns.lineplot(w, z, color = 'y')
plt.title('Payment, Balance, Cash Amount', fontsize = 20)
plt.show()
